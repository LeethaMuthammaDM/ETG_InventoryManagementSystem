# %%
Inventory= {2021001:{'name':'DairyMilk','ProductType':'confectionery','Quantity':100,'Price':60,'ManufacturedBy':'Cadbury',
                     'NetWeight':'59grams','Form':'Bar','ManufactureDate':'29July2021','IngredientType':'Vegetarian',
                     'Flavour':'Chocolate'},
          
          2021002:{'name':'Temptations','ProductType':'confectionery','Quantity':100,'Price':100,'ManufacturedBy':'Cadbury',
                     'NetWeight':'72grams','Form':'Bar','ManufactureDate':'29July2021','IngredientType':'Vegetarian',
                     'Flavour':'RumRasinChocolate'},
           2021003:{'name':'ChocolateCake','ProductType':'cake','Quantity':5,'Price':30,'ManufacturedBy':'Britania',
                     'NetWeight':'55grams','Form':'cake','ManufactureDate':'03Aug2021','IngredientType':'NonVegetarian',
                     'Flavour':'Chocolate'},
           2021004:{'name':'DarkFantasy','ProductType':'confectionary','Quantity':50,'Price':30,'ManufacturedBy':'Sunfeast',
                     'NetWeight':'300grams','Form':'Biscuit','ManufactureDate':'07Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'Chocolate'},
           2021005: {'name':'oreoBiscuit','ProductType':'confectionery','Quantity':9,'Price':50,'ManufacturedBy':'CadburyOreo',
                     'NetWeight':'120grams','Form':'Buscuit','ManufactureDate':'16Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'ChocolateAndVanilla'},
           2021006:{'name':'Lays','ProductType':'Potatochips','Quantity':200,'Price':10,'ManufacturedBy':'Lays',
                     'NetWeight':'52grams','Form':'chips','ManufactureDate':'16JUne2021','IngredientType':'Vegetarian',
                     'Flavour':'GreenOnionandSalt'},
           2021007:{'name':'Bourbon','ProductType':'confectionery','Quantity':70,'Price':10,'ManufacturedBy':'Britania',
                     'NetWeight':'100grams','Form':'Buscuit','ManufactureDate':'03June2021','IngredientType':'Vegetarian',
                     'Flavour':'Chocolate'},
           2021008:{'name':'KellogsCornflakes','ProductType':'grocery','Quantity':10,'Price':120,'ManufacturedBy':'Kellogs',
                     'NetWeight':'100grams','Form':'powder','ManufactureDate':'16Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'Corn'},
           2021009:{'name':'Knorsoup','ProductType':'grocery','Quantity':3,'Price':15,'ManufacturedBy':'Knor',
                     'NetWeight':'60grams','Form':'soupmix','ManufactureDate':'04Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'tomato'},
           2021010:{'name':'PillburyCakeMix','ProductType':'cakemix','Quantity':80,'Price':200,'ManufacturedBy':'Pillusbury',
                     'NetWeight':'120grams','Form':'powder','ManufactureDate':'16June2021','IngredientType':'Vegetarian',
                     'Flavour':'Strawberry'},
           2021011:{'name':'MTRUpmaMix','ProductType':'UpmaMix','Quantity':19,'Price':50,'ManufacturedBy':'MTR',
                     'NetWeight':'400grams','Form':'powder','ManufactureDate':'01Sep2021','IngredientType':'Vegetarian',
                     'Flavour':'FlourandVegetable'},
           2021012:{'name':'Puliogare','ProductType':'PuliogareMIx','Quantity':1,'Price':50,'ManufacturedBy':'Eastern',
                     'NetWeight':'120grams','Form':'powdermix','ManufactureDate':'04Nov2019','IngredientType':'Vegetarian',
                     'Flavour':'Tamarind'},
           2021013:{'name':'BiriyaniPowder','ProductType':'Masala','Quantity':59,'Price':50,'ManufacturedBy':'Aachi',
                     'NetWeight':'60grams','Form':'powder','ManufactureDate':'01Dec2019','IngredientType':'Vegetarian',
                     'Flavour':'Spices'},
           2021014:{'name':'SoyaSauce','ProductType':'sauce','Quantity':13,'Price':50,'ManufacturedBy':'Chings',
                     'NetWeight':'120grams','Form':'Liquid','ManufactureDate':'06Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'Soya'},
           2021015:{'name':'CornFlour','ProductType':'Flour','Quantity':49,'Price':30,'ManufacturedBy':'WeiKFiELD',
                     'NetWeight':'60grams','Form':'powder','ManufactureDate':'16Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'Corn'},
           2021016:{'name':'CocaCola','ProductType':'beverages','Quantity':78,'Price':20,'ManufacturedBy':'CocaCola',
                     'NetWeight':'250ml','Form':'beverageDrink','ManufactureDate':'16July2021','IngredientType':'Vegetarian',
                     'Flavour':'Cocacola'},
           2021017:{'name':'Fanta','ProductType':'beverages','Quantity':78,'Price':30,'ManufacturedBy':'CocaCola',
                     'NetWeight':'500ml','Form':'beverageDrink','ManufactureDate':'16July2021','IngredientType':'Vegetarian',
                     'Flavour':'Orange'},
           2021018:{'name':'Sprite','ProductType':'beverages','Quantity':18,'Price':20,'ManufacturedBy':'CocaCola',
                     'NetWeight':'1l','Form':'beverageDrink','ManufactureDate':'03Aug2021','IngredientType':'Vegetarian',
                     'Flavour':'Lime'},
           2021019:{'name':'JellyBox','ProductType':'confectionery','Quantity':68,'Price':40,'ManufacturedBy':'OrganicHut',
                     'NetWeight':'20grams','Form':'solid','ManufactureDate':'24Oct2019','IngredientType':'Vegetarian',
                     'Flavour':'Mixed'},
           2021020:{'name':'Cookies','ProductType':'confectionary','Quantity':18,'Price':300,'ManufacturedBy':'Chaayos',
                     'NetWeight':'200grams','Form':'cookie','ManufactureDate':'16July2021','IngredientType':'Vegetarian',
                     'Flavour':'flourandChocolate'},
           2021021:{'name':'Frooti','ProductType':'beverages','Quantity':78,'Price':20,'ManufacturedBy':'CocaCola',
                     'NetWeight':'250ml','Form':'beverageDrink','ManufactureDate':'16July2021','IngredientType':'Vegetarian',
                     'Flavour':'Mango'},
           2021022:{'name':'NightCream','ProductType':'Facecream','Quantity':2,'Price':150,'ManufacturedBy':'Himalayas',
                     'NetWeight':'60grams','Form':'Cream','ManufactureDate':'09Sep2019','IngredientType':'Vegetarian',
                     'Flavour':'Plum'},
           2021023:{'name':'NightCream','ProductType':'Facecream','Quantity':8,'Price':350,'ManufacturedBy':'Olay',
                     'NetWeight':'160grams','Form':'Cream','ManufactureDate':'09Jan2019','IngredientType':'Vegetarian',
                     'Flavour':'Olive'},
           2021024:{'name':'AntiDandruffShampoo','ProductType':'Haircare','Quantity':56,'Price':250,'ManufacturedBy':'Himalayas',
                     'NetWeight':'200ml','Form':'Shampoo','ManufactureDate':'19Sep2019','IngredientType':'Vegetarian',
                     'Flavour':'Bringraj'},
           2021025:{'name':'FootCream','ProductType':'BodyCare','Quantity':8,'Price':250,'ManufacturedBy':'Himalayas',
                     'NetWeight':'500grams','Form':'Cream','ManufactureDate':'09Aug2019','IngredientType':'Vegetarian',
                     'Flavour':'SeaWeed'},
           2021026:{'name':'BodyLotion','ProductType':'BodyCare','Quantity':45,'Price':130,'ManufacturedBy':'Himalayas',
                     'NetWeight':'600mlgrams','Form':'Lotion','ManufactureDate':'09Sep2019','IngredientType':'Vegetarian',
                     'Flavour':'Lavender'},
           2021027:{'name':'Eyecream','ProductType':'SkinCare','Quantity':8,'Price':150,'ManufacturedBy':'LorealParis',
                     'NetWeight':'30grams','Form':'Cream','ManufactureDate':'01Jan2019','IngredientType':'Vegetarian',
                     'Flavour':'Hylauronicacid'},
           2021028:{'name':'BodyWash','ProductType':'BathEssentials','Quantity':15,'Price':1050,'ManufacturedBy':'BodyShop',
                     'NetWeight':'300ml','Form':'Cream','ManufactureDate':'06June2021','IngredientType':'Vegetarian',
                     'Flavour':'Strawberry'},
           2021029:{'name':'BarOne','ProductType':'confectionery','Quantity':78,'Price':10,'ManufacturedBy':'Nestle',
                     'NetWeight':'30grams','Form':'Bar','ManufactureDate':'09June2021','IngredientType':'Vegetarian',
                     'Flavour':'ChpcolateanaCaramel'},
           2021030:{'name':'5Star','ProductType':'confectionery','Quantity':8,'Price':10,'ManufacturedBy':'Cadbury',
                     'NetWeight':'60grams','Form':'Cream','ManufactureDate':'09June2021','IngredientType':'Vegetarian',
                     'Flavour':'Colocolate'}}

# %% [markdown]
# # Adding New KeyValue to Dictionary accessing id¶

# %%
for i in Inventory:
    Inventory[i]['Offers']=int(input("Enter the offer for "+Inventory[i]['name']+":"))
# Out:
# Enter the offer for DairyMilk:0
# Enter the offer for Temptations:10
# Enter the offer for ChocolateCake:2
# Enter the offer for DarkFantasy:4
# Enter the offer for oreoBiscuit:0
# Enter the offer for Lays:0
# Enter the offer for Bourbon:0
# Enter the offer for KellogsCornflakes:0
# Enter the offer for Knorsoup:0
# Enter the offer for PillburyCakeMix:4
# Enter the offer for MTRUpmaMix:15
# Enter the offer for Puliogare:0
# Enter the offer for BiriyaniPowder:0
# Enter the offer for SoyaSauce:0
# Enter the offer for CornFlour:8
# Enter the offer for CocaCola:7
# Enter the offer for Fanta:0
# Enter the offer for Sprite:0
# Enter the offer for JellyBox:0
# Enter the offer for Cookies:30
# Enter the offer for Frooti:15
# Enter the offer for NightCream:1
# Enter the offer for NightCream:0
# Enter the offer for AntiDandruffShampoo:0
# Enter the offer for FootCream:0
# Enter the offer for BodyLotion:0
# Enter the offer for Eyecream:0
# Enter the offer for BodyWash:0
# ...

# %% [markdown]
# # Now Each Product Has new Attribute "OFFERS"

# %%
Inventory
# Out:
# {2021001: {'name': 'DairyMilk',
#   'ProductType': 'confectionery',
#   'Quantity': 100,
#   'Price': 60,
#   'ManufacturedBy': 'Cadbury',
#   'NetWeight': '59grams',
#   'Form': 'Bar',
#   'ManufactureDate': '29July2021',
#   'IngredientType': 'Vegetarian',
#   'Flavour': 'Chocolate',
#   'Offers': 0},
#  2021002: {'name': 'Temptations',
#   'ProductType': 'confectionery',
#   'Quantity': 100,
#   'Price': 100,
#   'ManufacturedBy': 'Cadbury',
#   'NetWeight': '72grams',
#   'Form': 'Bar',
#   'ManufactureDate': '29July2021',
#   'IngredientType': 'Vegetarian',
#   'Flavour': 'RumRasinChocolate',
#   'Offers': 10},
#  2021003: {'name': 'ChocolateCake',
#   'ProductType': 'cake',
#   'Quantity': 5,
#   'Price': 30,
#   'ManufacturedBy': 'Britania',
#   'NetWeight': '55grams',
#   'Form': 'cake',
#   'ManufactureDate': '03Aug2021',
#   'IngredientType': 'NonVegetarian',
#   'Flavour': 'Chocolate',
#   'Offers': 2},
#  2021004: {'name': 'DarkFantasy',
# ...

# %% [markdown]
# # Updating new values

# %%
Inventory[2021001]['Quantity'] #before
# Out:
# 100

# %%
Inventory[2021001]['Quantity']=Inventory[2021001]['Quantity'] + 100
Inventory[2021001]['Quantity'] #after(value is 100+100=200)
# Out:
# 200

# %% [markdown]
# # Uploading to json

# %%
import json
js = json.dumps(Inventory)
fd= open("Inventory.json",'w')
fd.write(js)
fd.close()

# %% [markdown]
# # Read the json file

# %%
fd=open("Inventory.json",'r')
txt=fd.read()
fd.close()
Inventory=json.loads(txt)

# %%
prodid=input("Enter the productid to be added:")
nameproduct=input("Enter the name:")
productType=input("Enter the ProductType:")
quantity=int(input("Enter the itemquantity:"))
price=int(input("Enter the Productprice:"))
manufacturer=input("Enter the manufacturer:")
weight=input("Enter the weight:")
form=input("Enter the form:")
mfdate=input("Enter the manufacturedate:")
ingredidient=input("Enter the ingredient:")
flv=input("Enter the flavor:")
off=int(input("Enter the offer:"))
Inventory[prodid]={'name':nameproduct,'ProductType':productType,'Quantity':quantity,'Price':price,'ManufacturedBy':manufacturer,
                  'NetWeight':weight,'Form':form,'ManufactureDate':mfdate,'IngredientType':ingredidient,'Flavour': flv,
                   'Offers':off}

js = json.dumps(Inventory)
fd= open("Inventory.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the productid to be added:2021031
# Enter the name:Pepsi
# Enter the ProductType:beverage
# Enter the itemquantity:9
# Enter the Productprice:30
# Enter the manufacturer:CocaCola
# Enter the weight:500ml
# Enter the form:Drink
# Enter the manufacturedate:01Sep2021
# Enter the ingredient:vegetarian
# Enter the flavor:cola
# Enter the offer:15

# %% [markdown]
# # This for loop is to display items in the inventory

# %%
for i,j in Inventory.items():
    print(i,':',j)          #now the inventory will have item new product
# Out:
# 2021001 : {'name': 'DairyMilk', 'ProductType': 'confectionery', 'Quantity': 200, 'Price': 60, 'ManufacturedBy': 'Cadbury', 'NetWeight': '59grams', 'Form': 'Bar', 'ManufactureDate': '29July2021', 'IngredientType': 'Vegetarian', 'Flavour': 'Chocolate', 'Offers': 0}
# 2021002 : {'name': 'Temptations', 'ProductType': 'confectionery', 'Quantity': 100, 'Price': 100, 'ManufacturedBy': 'Cadbury', 'NetWeight': '72grams', 'Form': 'Bar', 'ManufactureDate': '29July2021', 'IngredientType': 'Vegetarian', 'Flavour': 'RumRasinChocolate', 'Offers': 10}
# 2021003 : {'name': 'ChocolateCake', 'ProductType': 'cake', 'Quantity': 5, 'Price': 30, 'ManufacturedBy': 'Britania', 'NetWeight': '55grams', 'Form': 'cake', 'ManufactureDate': '03Aug2021', 'IngredientType': 'NonVegetarian', 'Flavour': 'Chocolate', 'Offers': 2}
# ...
